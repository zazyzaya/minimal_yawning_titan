# %%
import torch 
import networkx as nx 
import sys 

sys.path.append('..')
from env.yt_env import build_graph

# %%
def show_g(n,seed):
    x,ei = build_graph(n, seed=seed)
    g = nx.Graph([
        (ei[0][i].item(), ei[1][i].item())
        for i in range(ei.size(1))
    ])
    nx.draw(g)

# %%
show_g(10,1337)
# Out:
# Graph was disconnected. Trying again (0)
